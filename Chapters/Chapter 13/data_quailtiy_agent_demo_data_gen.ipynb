# %% [markdown]
# # Data Quality Agent — End-to-End Demo
#
# This notebook walks through three steps:
# 1. **Create** a `sales_transactions` table with synthetic data
# 2. **Log** the data quality agent as an MLflow PyFunc model
# 3. **Load** the model and generate data quality rules for the table

# %% [markdown]
# ## Configuration
#
# Set the catalog and schema where the demo table and model will live.
# Change these to match your workspace.

# %%
CATALOG = "demo"
SCHEMA  = "finance"
TABLE   = "sales_transactions"

spark.sql(f"CREATE CATALOG IF NOT EXISTS {CATALOG}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SCHEMA}")
spark.sql(f"USE CATALOG {CATALOG}")
spark.sql(f"USE SCHEMA {SCHEMA}")
